# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
m = 3,4

# %%
m,n = (3,4)

# %%
flag,img = vid.read()

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
for i in range(100):
    flag, img = vid.read()
    if flag:
        cv2.imshow('Preview', img)
        cv2.waitKey(1)

# %%
while True:
    flag, img = vid.read()
    if flag:
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        #Processing Code
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        th,img_bw = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY_INV)
        #print(type(img_gray))
        #break
        ##

        cv2.imshow('Preview', img_bw)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        print('No Frames')
        break

cv2.destroyAllWindows()

vid.release()

# %%
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        #Processing Code
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        th,img_bw = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY_INV)
        x,y,w,h = (250,200,100,100)
        img_cropped = img[y:y+h, x:x+w, :]
        #print(type(img_gray))
        #break
        ##

        cv2.imshow('Preview', img_cropped)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        print('No Frames')
        break

cv2.destroyAllWindows()

vid.release()

# %%
vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        #Processing Code
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        th,img_bw = cv2.threshold(img_gray, 100, 255, cv2.THRESH_BINARY_INV)
        x,y,w,h = (250,200,100,100)
        img_cropped = img[y:y+h, x:x+w, :]

        cv2.rectangle(img, pt1 = (x,y), pt2 = (x+w, y+h), color=(0,0,255))
        #print(type(img_gray))
        #break
        ##

        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
    else:
        print('No Frames')
        break

cv2.destroyAllWindows()

vid.release()

# %%
#FETCH ASCII VALUE
ord('a')
# Out:
# 97

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
k
# Out:
# (True,
#  array([[[29, 26, 38],
#          [29, 28, 34],
#          [28, 28, 28],
#          ...,
#          [22, 22, 22],
#          [22, 22, 22],
#          [22, 22, 22]],
#
#         [[29, 28, 35],
#          [28, 27, 31],
#          [28, 28, 28],
#          ...,
#          [22, 22, 22],
#          [22, 22, 22],
#          [22, 22, 22]],
#
#         [[28, 28, 28],
#          [28, 28, 28],
#          [28, 28, 28],
#          ...,
#          [22, 22, 22],
#          [22, 22, 22],
#          [22, 22, 22]],
#
#         ...,
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [ 9,  9,  9],
#          ...,
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5]],
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [ 9,  9,  9],
#          ...,
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5]],
#
#         [[ 9,  9,  9],
#          [ 9,  9,  9],
#          [ 9,  9,  9],
#          ...,
#          [ 5,  5,  5],
#          [ 5,  5,  5],
#          [ 5,  5,  5]]], dtype=uint8))

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#       --------------------------------------- 0.2/7.6 MB 10.2 MB/s eta 0:00:01
#      -- ------------------------------------- 0.4/7.6 MB 5.0 MB/s eta 0:00:02
#      -- ------------------------------------- 0.5/7.6 MB 3.8 MB/s eta 0:00:02
#      --- ------------------------------------ 0.6/7.6 MB 4.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 1.0/7.6 MB 4.4 MB/s eta 0:00:02
#      ------ --------------------------------- 1.2/7.6 MB 4.2 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3/7.6 MB 4.1 MB/s eta 0:00:02
#      ------ --------------------------------- 1.3